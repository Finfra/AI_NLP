# %%
# !pip install nltk
# !pip install konlpy

# %%
import nltk
nltk.download('punkt')

# Sentence tokenizer
from nltk.tokenize import sent_tokenize
text = "His barber kept his word. But keeping such a huge secret to himself was driving him crazy. Finally, the barber went up a mountain and almost to the edge of a cliff. He dug a hole in the midst of some reeds. He looked about, to mae sure no one was near."
print(sent_tokenize(text))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['His barber kept his word.', 'But keeping such a huge secret to himself was driving him crazy.', 'Finally, the barber went up a mountain and almost to the edge of a cliff.', 'He dug a hole in the midst of some reeds.', 'He looked about, to mae sure no one was near.']

# %%
# Sentence tokenizer. Ph.D. 구두점 예제
from nltk.tokenize import sent_tokenize
text = "I am actively looking for Ph.D. students. and you are a Ph.D. student."
print(sent_tokenize(text))
# Out:
# ['I am actively looking for Ph.D. students.', 'and you are a Ph.D. student.']

# %%
# Word tokenizer : 띄어쓰기 단위로 구분
from nltk.tokenize import word_tokenize  
s="딥러닝은 어렵다. 나는 딥러닝을 좋아한다"

print(word_tokenize("딥러닝은 어렵다. 나는 딥러닝을 좋아한다"))
# Out:
# ['딥러닝은', '어렵다', '.', '나는', '딥러닝을', '좋아한다']

# %%
# Word tokenizer : Do와 n't로 구분 's 도 별도로 구분
from nltk.tokenize import word_tokenize  

text ="Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop."
print(word_tokenize(text))
# Out:
# ['Do', "n't", 'be', 'fooled', 'by', 'the', 'dark', 'sounding', 'name', ',', 'Mr.', 'Jone', "'s", 'Orphanage', 'is', 'as', 'cheery', 'as', 'cheery', 'goes', 'for', 'a', 'pastry', 'shop', '.']

# %%
# 단어 단위의 토큰화
from nltk.tokenize import WordPunctTokenizer  
print(WordPunctTokenizer().tokenize("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop."))
# Out:
# ['Don', "'", 't', 'be', 'fooled', 'by', 'the', 'dark', 'sounding', 'name', ',', 'Mr', '.', 'Jone', "'", 's', 'Orphanage', 'is', 'as', 'cheery', 'as', 'cheery', 'goes', 'for', 'a', 'pastry', 'shop', '.']

# %%
# 단어의 품사태깅 :POS tagging with TreebankWordTokenizer
text = "질문이 있으면 웹사이트에 거침없이 Question 해주세요"

from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
text = tokenizer.tokenize(text)
text
# Out:
# ['질문이', '있으면', '웹사이트에', '거침없이', 'Question', '해주세요']

# %%
# POS tagging

from nltk import pos_tag
nltk.download('averaged_perceptron_tagger')
pos_tag(text)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [('질문이', 'JJ'),
#  ('있으면', 'NNP'),
#  ('웹사이트에', 'NNP'),
#  ('거침없이', 'NNP'),
#  ('Question', 'NNP'),
#  ('해주세요', 'NN')]

# %%
text = "Don't hesitate to ask questions"

from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
text = tokenizer.tokenize(text)
text
# Out:
# ['Do', "n't", 'hesitate', 'to', 'ask', 'questions']

# %%
from nltk import pos_tag
nltk.download('averaged_perceptron_tagger')
pos_tag(text)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('Do', 'VBP'),
#  ("n't", 'RB'),
#  ('hesitate', 'VB'),
#  ('to', 'TO'),
#  ('ask', 'VB'),
#  ('questions', 'NNS')]

# %%
text = "Don't hesitate to ask questions"

from nltk.tokenize import WordPunctTokenizer
tokenizer = WordPunctTokenizer()
text = tokenizer.tokenize(text)
text
# Out:
# ['Don', "'", 't', 'hesitate', 'to', 'ask', 'questions']

# %%
from nltk import pos_tag
pos_tag(text)
# Out:
# [('Don', 'NNP'),
#  ("'", 'POS'),
#  ('t', 'NN'),
#  ('hesitate', 'NN'),
#  ('to', 'TO'),
#  ('ask', 'VB'),
#  ('questions', 'NNS')]
