# %%
def find_bigrams(text):
    return [ (text[i], text[i+1]) for i in range(len(text) - 1)]

s='떳다 떳다 비행기 날아라 날아라 높이 높이 날아라 우리 비행기 내가 만든 비행기 날아라 날아라 높이 높이 날아라 우리 비행기'  

## 형태소 분석 필요

find_bigrams(s.split())
# Out:
# [('떳다', '떳다'),
#  ('떳다', '비행기'),
#  ('비행기', '날아라'),
#  ('날아라', '날아라'),
#  ('날아라', '높이'),
#  ('높이', '높이'),
#  ('높이', '날아라'),
#  ('날아라', '우리'),
#  ('우리', '비행기'),
#  ('비행기', '내가'),
#  ('내가', '만든'),
#  ('만든', '비행기'),
#  ('비행기', '날아라'),
#  ('날아라', '날아라'),
#  ('날아라', '높이'),
#  ('높이', '높이'),
#  ('높이', '날아라'),
#  ('날아라', '우리'),
#  ('우리', '비행기')]

# %%
# !bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh)
# !pip install konlpy
# Out:
# mecab-ko is already installed
# mecab-ko-dic is already installed
# mecab-python is already installed
# Done.
# ...

# %%
import sklearn.feature_extraction.text

ngram_size = 2
train_set = ['떳다 떳다 비행기 날아라 날아라 높이 높이 날아라 ', '우리 비행기 내가 만든 비행기 날아라 날아라 높이 높이 날아라 우리 비행기']

vectorizer = sklearn.feature_extraction.text.CountVectorizer(ngram_range=(ngram_size,ngram_size))
vectorizer.fit(train_set) # build ngram dictionary
ngram = vectorizer.transform(train_set) # get ngram
print('ngram: {0}\n'.format(ngram))
print('ngram.shape: {0}'.format(ngram.shape))
print('vectorizer.vocabulary_: {0}'.format(vectorizer.vocabulary_))
# Out:
# ngram:   (0, 0)	1
#   (0, 1)	1
#   (0, 4)	1
#   (0, 5)	1
#   (0, 6)	1
#   (0, 7)	1
#   (0, 9)	1
#   (1, 0)	1
#   (1, 1)	1
#   (1, 2)	1
#   (1, 3)	1
#   (1, 4)	1
#   (1, 5)	1
#   (1, 8)	1
#   (1, 9)	1
#   (1, 10)	1
#   (1, 11)	2
#
# ngram.shape: (2, 12)
# vectorizer.vocabulary_: {'떳다 떳다': 6, '떳다 비행기': 7, '비행기 날아라': 9, '날아라 날아라': 0, '날아라 높이': 1, '높이 높이': 5, '높이 날아라': 4, '우리 비행기': 11, '비행기 내가': 10, '내가 만든': 3, '만든 비행기': 8, '날아라 우리': 2}
