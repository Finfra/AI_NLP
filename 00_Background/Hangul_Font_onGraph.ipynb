# %% [markdown]
# # 코랩에서 오작동 할 수 있음.
# - 오작동 하면 "Restart runtime and run all cells in notebook"

# %%
# !apt install fonts-nanum-coding
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum-coding is already the newest version (2.5-1).
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.

# %%
from matplotlib import font_manager  as fm
import matplotlib.pyplot as plt
nc = fm.FontProperties(fname='/usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf' )
plt.text(0.3, 0.3, u'한글', size=100, fontproperties=nc)
# Out:
# Text(0.3, 0.3, '한글')

# %%
from matplotlib import font_manager
for font in font_manager.fontManager.ttflist:
    if 'anum' in font.name:
        print(font.name, font.fname)
# Out:
# NanumGothicCoding /usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf
# NanumGothicCoding /usr/share/fonts/truetype/nanum/NanumGothicCoding-Bold.ttf

# %%
from matplotlib import font_manager
fm._rebuild()
path = '/usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf'  
font_name = fm.FontProperties(fname=path, size=10).get_name()
plt.rc('font', family=font_name)
plt.title(u'한글')
plt.plot(range(10),range(10),'r')
plt.show()
