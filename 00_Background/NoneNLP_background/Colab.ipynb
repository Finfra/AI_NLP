# %% [markdown]
# # Source Code Download

# %%
# %%bash
# cd /content/drive/MyDrive/
# rm -rf AI_CNN_RNN
# git clone https://github.com/Finfra/AI_CNN_RNN

# %% [markdown]
# # Verion 확인

# %%
import sys
sys.version

# %%
import tensorflow as tf
tf.__version__

# %% [markdown]
# # Magic command

# %%
# !ls
# !pwd

# %%
# !cd
# !pwd

# %%
# %cd /
# !pwd

# %%
# %cd /content

# %% [markdown]
# # GPU 사용여부 확인
# * 메뉴 → Runtime → Change Runtime Type → Hardware Accelerator를 GPU로 변경

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')

# %% [markdown]
# # 설치

# %% [markdown]
# ## pip 설치
# 라이브러리가 없는 경우 pip 를 통해 설치를 해준다.

# %%
# !pip install konlpy

# %% [markdown]
# 설치된 라이브러리는 dir 명령어를 통해 기능들을 확인할 수 있다.

# %%
import konlpy
dir(konlpy)

# %% [markdown]
# ## apt install
# apt install 도 설치 가능하다.

# %%
# !apt install imagemagick

# %%
# !convert -version

# %% [markdown]
# # Colab 연결유지
# 크롬에서 F12 버튼을 눌러 개발자 도구를 열어주고, Console 탭에 아래 코드를 쳐주면 긴 작업시에 연결유지를 도와준다.(코드 상의 인터벌은 60초이다.)

# %%
function ClickConnect() {
    var buttons = document.querySelectorAll("colab-dialog.yes-no-dialog paper-button#cancel"); 
    buttons.forEach(function(btn) { 
        btn.click(); 
    }); 
    console.log("Colab 연결 유지"); 
    document.querySelector("colab-toolbar-button#connect").click(); 
} 
setInterval(ClickConnect,60*1000);

# %% [markdown]
# buffered data was truncated after reaching the output size limit 에러 방지를 위해 현재 출력창을 자동으로 지워주는 코드

# %%
function CleanCurrentOutput(){ 
    var btn = document.querySelector(".output-icon.clear_outputs_enabled.output-icon-selected[title$='현재 실행 중...'] iron-icon[command=clear-focused-or-selected-outputs]"); 
    if(btn) { console.log("30분마다 출력 지우기");
     btn.click(); 
    } 
} 
setInterval(CleanCurrentOutput,30*60*1000);
