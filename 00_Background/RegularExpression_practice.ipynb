# %%
import re
dir(re)

# %%
corpus="""aa
aa<br>bb
cccd
"""

# %%
corpus=corpus.split()
corpus
# Out:
# ['aa', 'aa<br>bb', 'cccd']

# %%
#ret=re.sub('^aa$',"xx",corpus)
ret=[re.sub('^aa$',"xx",i) for i in corpus ]
ret
# Out:
# ['xx', 'aa<br>bb', 'cccd']

# %%
corpus=["aa",
        "aabb",
        "cccd"]
[re.sub('^aa$',"xx",i) for i in corpus ]
# Out:
# ['xx', 'aabb', 'cccd']

# %%
corpus="""aa
aabb
cccd
"""


re.findall('aa.*bb',corpus,re.DOTALL)
# Out:
# ['aa\naabb']
